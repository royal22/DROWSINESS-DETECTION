# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statistics as st

db = pd.read_csv("C:/Users/Raj/Documents/Drowsiness_data.csv")
y = db['overall']
x = db['Year']
z = db['drowsy_driving']

# %%
mi = plt.plot(x, y, color='#ff6622', marker='o')
plt.xlabel('Year ------>')
plt.ylabel('Overall Crashes ------>')
plt.title('Drowsiness')
plt.show()

# %%
mi = plt.plot(x, z, color='#ff6622', marker='o')
plt.xlabel('Year ------>')
plt.ylabel('Drowsy_Driving ------>')
plt.title('Drowsiness')
plt.show()

# %%
mi = plt.plot(z, y, color='#ff6622', marker='o')
plt.xlabel('Overall Crashes ------>')
plt.ylabel('Drowsy Driving ------>')
plt.title('Drowsiness')
plt.show()

# %%
sns.distplot(db['Year'])

# %%
sns.jointplot (x='overall', y='Year', data=db, kind='reg')
# Out:
# C:\Users\Raj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Raj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.barplot(x='overall', y='drowsy_driving', data=db)

# %%
sns.pairplot(db)

# %%
sns.swarmplot (y='overall', x='Year', data=db, hue='drowsy_driving')
